# %%
import pandas as pd

catalog = pd.read_csv("catalog.csv", encoding="utf-8")
catalog
# Out:
#       id                                               name  \
# 0     33                                   ICE-CT avec bras
# 1     34                       SHOCKMASTER 500 avec V-Actor
# 2      2                                          THERMO TK
# 3      3                                           ENPULS 2
# 4      8                                             CRYO 6
# 5      9                                         ENPULS PRO
# 6     10                                          ENPULS 2N
# 7     27                                          OPTON PRO
# 8     51                                            OPTON 4
# 9     52                Pack Onde de choc Enpuls 2 + Cryo 6
# 10    28                                               HPL7
# 11    38                                RADIALES MOBILE RPW
# 12    39              Ondes de choc Focalisée INTELECT F-SW
# 13    40     Ondes de choc radiale et infrason INTELECT RPW
# 14    92                         Laserthérapie INTELECT VET
# 15   391        LASER HAUTE PUISSANCE INTELECT® HPL15 (15W)
# 16   392          LASER HAUTE PUISSANCE INTELECT® HPL7 (7W)
# 17   393                  Table Traction Triton 3-M 2 roues
# 18   465              Ultrason Intelect mobile sur guéridon
# 19   471  Intelect neo Ultrason + laser + électrostimula...
# 20   472  Intelect neo Ultrason +électrostimulation 4 vo...
# 21    31                                  SPECTRA ESSENTIAL
# 22    35                                           PERFORMA
# 23   366                               Kinetec 6080 (coude)
# 24   367                           Kinetec BREVA (cheville)
# 25   368               Kinetec CENTURA - 2 moteurs (épaule)
# 26   369                   Kinetec KINEVIA DUO - 4665009451
# 27   370                   Kinetec MAESTRA (main & poignet)
# 28   371                  Kinetec PERFORMA - Coques confort
# 29   372             Kinetec PRIMA ADVANCE - Coques confort
# ..   ...                                                ...
# 155  518  Fauteuil d’hospitalisation de jour - CLAVIA FC...
# 156  503               Scanner 3D deluXe - OpenTechnologies
# 157  504                Scanner 3D smaRt - OpenTechnologies
# 158  508                 Scanner 3D eaSy - OpenTechnologies
# 159  509                Scanner 3D NeWay - OpenTechnologies
# 160  519               Scanner 3D Click - Open Technologies
# 161  537                Scanner 3D smaRt - OpenTechnologies
# 162  510                    Scanner 3D Goscan 20 - Creaform
# 163  520                    Scanner 3D Goscan 50 - Creaform
# 164  523            Imprimante 3D résine XFAB 2000 PD - DWS
# 165  524            Imprimante 3D résine XFAB 2500 PD - DWS
# 166  525            Imprimante 3D résine XFAB 3500 PD - DWS
# 167  526            Imprimante 3D métal My sint 100 - SISMA
# 168  527         Imprimante 3D métal My sint 100 RM - SISMA
# 169  529                Imprimante 3D filaire Stream 30 MK2
# 170  530              Imprimante 3D filaire Stream 30 Ultra
# 171  531                Imprimante 3D filaire Stream 20 MK2
# 172  532                              TruScan EEG 24 canaux
# 173  533                     TruTrace EMG portable 2 canaux
# 174  534                    SomniPro PSG portable 35 canaux
# 175  535  Stimulateur magnétique transcranienne : rTMS D...
# 176  536                          TruScan Neurofeedback 2ch
# 177  538         Ventilateur de transport MEDUMAT TRANSPORT
# 178  560  Ventilateur de transport Light" MEDUMAT Standa...
# 179  561        Aspirateur de mucosité portable ACCUVAC Pro
# 180  562  Aspirateur de mucosité portable ACCUVAC Lite (...
# 181  563  Ventilateur de secours et d'urgence MEDUMAT Ea...
# 182  564          Ventilateur de secours MEDUMAT Standard a
# 183  565         Moniteur défibrillateur MEDUCORE Standard²
# 184  569                                         Julie TEST
#
#                  name.1           reference_catalog  \
# 0                 Gymna                      343002
# 1                 Gymna               338030+337414
# 2                Zimmer                     ZIM3000
# 3                Zimmer                     ZIM0100
# 4                Zimmer                     ZIM0600
# 5                Zimmer                     ZIM0200
# 6                Zimmer                     ZIM0150
# 7                Zimmer                     ZIM2000
# 8                Zimmer                     ZIM2100
# 9                Zimmer                     ZIM9001
# 10          Chattanooga                     COM6000
# 11          Chattanooga                     COM0100
# 12          Chattanooga                       21090
# 13          Chattanooga                        2074
# 14          Chattanooga  Laserthérapie Intelect Vet
# 15          Chattanooga                      CH2979
# 16          Chattanooga                        2879
# 17          Chattanooga                      CH3263
# 18          Chattanooga                       27800
# 19          Chattanooga                      70 005
# 20          Chattanooga                      70 004
# 21              Kinetec                     TEC0510
# 22              Kinetec                     TEC0550
# 23              Kinetec                  4621000802
# 24              Kinetec                  4621006502
# 25              Kinetec                  4621003002
# 26              Kinetec                  4665009451
# 27              Kinetec                  4621005002
# 28              Kinetec                  4621001842
# 29              Kinetec                    46210080
# ..                  ...                         ...
# 155         Bmb Medical                  CLVE4-7FCD
# 156   Open Technologies                 OPEN-DELUXE
# 157   Open Technologies              OPEN-SMART BIG
# 158   Open Technologies                   OPEN-EASY
# 159   Open Technologies                  OPEN-NEWAY
# 160   Open Technologies                  OPEN-CLICK
# 161   Open Technologies            OPEN-SMART SMALL
# 162            Creaform               CREA-GOSCAN20
# 163            Creaform               CREA-GOSCAN50
# 164                 Dws                    DWS XFAB
# 165                 Dws            DWS XFAB 2500 PD
# 166                 Dws            DWS XFAB 3500 PD
# 167               Sisma             SIS - MYSINT100
# 168               Sisma          SIS - MYSINT100 RM
# 169             Volumic          VOLU STREAM 30 MK2
# 170             Volumic        VOLU STREAM 30 ULTRA
# 171             Volumic         VOLU STREAM 20 DUAL
# 172              Deymed                    TS 24 LT
# 173              Deymed                      TT-002
# 174              Deymed                    SP-35LTW
# 175              Deymed                     DM-XT10
# 176              Deymed                      BF-002
# 177  Weinmann Emergency                     WM 9620
# 178  Weinmann Emergency                     WM 9895
# 179  Weinmann Emergency                     WM11635
# 180  Weinmann Emergency                    WM 11735
# 181  Weinmann Emergency                    WM 28161
# 182  Weinmann Emergency                    WM 22880
# 183  Weinmann Emergency                     WM 9900
# 184                 New                   123456789
#
#                                 reference_manufacturer  selling_price
# 0                                               343002        7216.67
# 1                                        338030+337414       13079.20
# 2                                              ZIM3000        9583.00
# 3                                              ZIM0100        7491.00
# 4                                              ZIM0600        5741.00
# 5                                              ZIM0200       12083.00
# 6                                              ZIM0150        9916.00
# 7                                              ZIM2000       12658.00
# 8                                              ZIM2100        8250.00
# 9                                              ZIM9001       13082.00
# 10                                             COM6000        7491.00
# 11                                             COM0100        9165.00
# 12                                               21090       21777.00
# 13                                                2074       10000.00
# 14                          Laserthérapie Intelect Vet        9500.00
# 15                                                2979       15825.00
# 16                                                2879        7491.67
# 17                                                4749        1893.33
# 18                                               27800        1575.00
# 19                                              70 005        6360.00
# 20                                              70 004        6097.00
# 21                                             TEC0510        3957.00
# 22                                             TEC0550        5982.00
# 23                  Kinetec 6080™ (coude) - 4621000802        6368.00
# 24              Kinetec BREVA™ (cheville) - 4621006502        5474.00
# 25   Kinetec CENTURA™ - 2 moteurs (épaule) - 462100...        8697.00
# 26                   Kinetec KINEVIA DUO™ - 4665009451        5443.00
# 27      Kinetec MAESTRA™ (main & poignet) - 4621005002        6252.00
# 28     Kinetec PERFORMA™ • Coques confort - 4621001842        5987.00
# 29   Kinetec PRIMA ADVANCE™ • Coques confort - 4621...        3870.00
# ..                                                 ...            ...
# 155                                         CLVE4-7FCD        2736.00
# 156                                             DELUXE       11544.43
# 157                                          SMART BIG       10099.98
# 158                                               EASY        9211.10
# 159                                              NEWAY       13099.99
# 160                                              CLICK        9988.87
# 161                                        SMART SMALL       10099.98
# 162                                      SYS‐G3D‐PGO20       24665.98
# 163                                      SYS‐G3D‐PGO50       24665.98
# 164                                           10100026        8666.67
# 165                                           10100035       15188.86
# 166                                           10100038       29553.30
# 167                                            699884E      229247.00
# 168                                            699887E      243854.33
# 169                                           VS30PMK2       48883.31
# 170                                    Stream 30 Ultra        6675.53
# 171                                            VS20PRO        4159.97
# 172                                           TS 24 LT       10900.00
# 173                                             TT-002       13900.00
# 174                                           SP-35LTW       15500.00
# 175                                            DM-XT10       32990.00
# 176                                             BF-002        7500.00
# 177                                            WM 9620        9703.00
# 178                                            WM 9895        4449.60
# 179                                            WM11635        1672.00
# 180                                           WM 11735        1833.00
# 181                                           WM 28161        2069.90
# 182                                           WM 22880        3261.70
# 183                                            WM 9900        5591.25
# 184                                          123456789        5000.00
#
# [185 rows x 6 columns]

# %%
names = [row[1] for row in catalog]
names = names[1:]
print(names[:5])
marques = [row[2] for row in catalog]
marques = marques[1:]
print(marques[:5])

marque_counts = {}
for marque in marques:
    if marque not in marque_counts:
        marque_counts[marque] = 0
    marque_counts[marque] +=1
    
print(marque_counts)
# Out:
# ['ICE-CT avec bras', 'SHOCKMASTER 500 avec V-Actor', 'THERMO TK', 'ENPULS 2', 'CRYO 6']
# ['Gymna', 'Gymna', 'Zimmer', 'Zimmer', 'Zimmer']
# {'Gymna': 2, 'Zimmer': 8, 'Chattanooga': 11, 'Kinetec': 12, 'Samsung': 1, 'Esaote': 2, 'Ysy Medical': 1, 'Starvac': 1, 'INTERSON': 4, 'Genin Medical': 13, 'Anasonic': 4, 'Idetec': 4, 'Idevet': 5, 'Waldmann': 3, 'Derungs': 10, 'PENTAX Medical': 13, 'Phenix': 1, 'Canon': 4, 'DoctorVet': 1, 'GlobusVet': 1, 'K-Laser': 1, 'Epson': 2, 'Newmed': 4, 'Biomerieux': 1, 'ML FUSION': 5, 'Winelec': 1, 'Lojer': 2, 'Kipp': 1, 'Broadsound Corporation': 5, 'Djo France': 1, 'Nox Medical': 1, 'Carestream Dental': 1, 'Tech Med Tm': 3, 'Vatech': 3, 'Rocamed': 3, 'Eureduc': 1, 'Planmed': 1, 'Dms': 3, 'Liftup': 1, 'Winncare': 2, 'Eco-dex': 1, 'Praxis': 1, 'Bmb Medical': 11, 'Open Technologies': 6, 'Creaform': 2, 'Dws': 3, 'Sisma': 2, 'Volumic': 3, 'Deymed': 5, 'Weinmann Emergency': 7, 'New': 1}

# %%
physio = [['Douleurs et rééducation', 'https://www.physiotherapie.com/physiotherapie/electrotherapie/electrotherapie-portable/douleurs-reeducation.html'], ['Appareils sport et fitness', 'https://www.physiotherapie.com/physiotherapie/electrotherapie/electrotherapie-portable/appareils-sport-fitness.html'], ['Électrodes et gels', 'https://www.physiotherapie.com/physiotherapie/electrotherapie/accessoires-electrotherapie/electrodes-gels.html'], ['Câbles et adaptateurs', 'https://www.physiotherapie.com/physiotherapie/electrotherapie/accessoires-electrotherapie/cables-adaptateurs.html'], ['Batteries et chargeurs', 'https://www.physiotherapie.com/physiotherapie/electrotherapie/accessoires-electrotherapie/chargeurs-batteries.html'], ['Accessoires Divers', 'https://www.physiotherapie.com/physiotherapie/electrotherapie/accessoires-electrotherapie/accessoires-divers.html'], ['Tables électriques Naggura', 'https://www.physiotherapie.com/tables-et-mobiliers/tables-de-massage/tables-electriques.html?manufacturer=2354'], ['Tables électriques Galaxy', 'https://www.physiotherapie.com/catalogsearch/result/index/?cat=180&q=GALAXY'], ['Tables électriques Ferrox', 'https://www.physiotherapie.com/tables-et-mobiliers/tables-de-massage/tables-electriques.html?manufacturer=381'], ['Tables électriques FERROX I-TREAT', 'https://www.physiotherapie.com/catalogsearch/result/?q=I-Treat'], ['Tables électriques Montane', 'https://www.physiotherapie.com/catalogsearch/result/?q=Table+MONTANE'], ['Tables électriques Ecopostural', 'https://www.physiotherapie.com/catalogsearch/result/?q=ecopostural'], ['Gants vinyle non stériles non poudrés', 'https://www.physiotherapie.com/gants-vinyle-non-steriles-non-poudres-3413.html'], ['Gants vinyle non stériles légèrement poudrés', 'https://www.physiotherapie.com/gants-vinyle-legerement-poudres-3414.html'], ['Gants latex non stériles non poudrés', 'https://www.physiotherapie.com/gants-latex-non-steriles-non-poudres-3419.html'], ['Gants latex non stériles poudrés', 'https://www.physiotherapie.com/gants-latex-non-steriles-poudres-3415.html'], ['Savon doux haute fréquence ANIOS', 'https://www.physiotherapie.com/savon-doux-haute-frequence.html'], ['Savon haute fréquence pH neutre ALKADOUX', 'https://www.physiotherapie.com/alkapharm-savon-haute-frequence-a-ph-neutre.html'], ['Détergent désinfectant des sols ANIOS', 'https://www.physiotherapie.com/detergent-desinfectant-des-sols-sun-way.html'], ['Nettoyant-désinfectant des sols ALKADDH', 'https://www.physiotherapie.com/nettoyant-desinfectant-des-sols-alkaddh.html'], ["Boîte de 120 lingettes LINGET'ANIOS", 'https://www.physiotherapie.com/boite-de-120-lingettes-alkalingettes-3111.html'], ['Masques chirugicaux 3 plis', 'https://www.physiotherapie.com/masques-chirugicaux-3-plis.html']]

# %%
import pandas as pd

physio_df = pd.read_excel("catalog_physio_20181129.xlsx", encoding="utf-8")

# %%
physio_df
# Out:
#         id                                                nom  \
# 0       82                                       GLOBUS Elite
# 1       85                                     GLOBUS Duo Pro
# 2     3116                                      SPORECUP XTR4
# 3     5884                                  GLOBUS Activa 700
# 4     5889                               GLOBUS Triathlon Pro
# 5     5893                                  GLOBUS The Winner
# 6     5931                                   GLOBUS Elite SII
# 7     5939                                 GLOBUS Premium 400
# 8    11066                          VEINOPLUS Veinoplus Sport
# 9      115            GENERIQUE Electrodes 50x90 mm 2 sorties
# 10     222              GENERIQUE Electrodes carrées 50x50 mm
# 11     223                      GENERIQUE Electrodes 50x90 mm
# 12     227                 GENERIQUE Flacon de gel conducteur
# 13   21783           CEFAR-COMPEX Kit Electrodes Cefar-Compex
# 14      14  CEFAR-COMPEX Jeu 2 electrodes à Fil Dura-stick...
# 15     116            CEFAR-COMPEX Electrodes Premium 50x50mm
# 16     117           CEFAR-COMPEX Electrodes Premium 50x90 mm
# 17     187           CEFAR-COMPEX Jeu de 4 électrodes Ø 32 mm
# 18     188             CEFAR-COMPEX Electrodes rondes Ø 50 mm
# 19     190  CEFAR-COMPEX Jeu de 4 électrodes à Fil Dura-st...
# 20     191  CEFAR-COMPEX Jeu de 4 électrodes à Fil Dura-st...
# 21     199    CEFAR-COMPEX Electrodes Peaux sensibles carrées
# 22     317        GENERIQUE Kit Electrodes PHYSIOTHERAPIE.com
# 23     351             CEFAR-COMPEX Electrodes CLIP 50x100 mm
# 24     352                     CEFAR Electrodes CLIP 50x50 mm
# 25     361  COMPEX Jeu de 2 électrodes Performance SNAP 50...
# 26     362  COMPEX Jeu de 4 électrodes Performance SNAP 50...
# 27     426  PHYSIOTHERAPIE.com Electrodes Elastomère au mètre
# 28    1215           CHATTANOOGA Flacon de Gel ultrason 250ml
# 29    2542                  CEFAR Lot de 4 Electrodes Carbone
# ..     ...                                                ...
# 157   3148  CEFAR Câble bipolaire pour les Cefar X2 et Pri...
# 158   3451            CHATTANOOGA Câbles Stim Intelect Mobile
# 159   3528  SPORECUP Cable bipolaire SPORECUP pour Tens Do...
# 160   3560  CHATTANOOGA Câble adaptateur 2 fiches bananes ...
# 161     59                      CEFAR Chargeur Cefar Rehab X4
# 162     60  CEFAR Batterie pour Myo 4, Rehab 4 Pro, Cefar ...
# 163    196      GLOBUS Chargeur Globus pour appareil 4 canaux
# 164    197      GLOBUS Batterie Globus pour appareil 4 canaux
# 165    200        GENERIQUE Kit Chargeur universel + piles AA
# 166    224         GENERIQUE Piles rechargeables AA (4 piles)
# 167    225        GENERIQUE Piles rechargeables AAA (3 piles)
# 168    232       GENERIQUE Kit Chargeur universel + piles AAA
# 169    355           CEFAR Batterie pour Activ X4 et Rehab X4
# 170    363                 COMPEX Batterie 4 cellules 941.210
# 171    364                 COMPEX Batterie 6 cellules 941.100
# 172    366                 COMPEX Chargeur 4 cellules 683 010
# 173    438                CEFAR Chargeur pour PHYSIO 4 et MYO
# 174    439             CEFAR Batterie pour PHYSIO 4 et MYO II
# 175    442                         COMPEX Chargeur 6 cellules
# 176    445                    GLOBUS Chargeur 4 canaux (110V)
# 177    446  GLOBUS Batterie Globus pour Magnum / Medisound...
# 178   3219  COMPEX Batterie 4 cellules 941.213 pour Compex...
# 179   3313            COMPEX Kit Chargeur externe de batterie
# 180   3315  SPORECUP Batterie pour Tens eco 2, XTR2, EMP2 ...
# 181   3784  GLOBUS Chargeur Globus Magnum XL pro / L, Phys...
# 182   9638      GLOBUS Batterie Globus pour appareil 2 canaux
# 183   9640  GLOBUS Chargeur Globus pour nouvel appareil 4 ...
# 184   9782  SPORECUP Chargeur pour EMP2, TENS, Urostim, XT...
# 185  12760            GLOBUS Batterie pour Globus Genesy 3000
# 186  20185  GLOBUS Chargeur Globus pour Medisound Pro II /...
#
#                       categorie           reference  prix
# 0    Appareils sport et fitness              GL-ELI   249
# 1    Appareils sport et fitness              GL-PAL   129
# 2    Appareils sport et fitness              SP-XT4   229
# 3    Appareils sport et fitness             GL-A700   399
# 4    Appareils sport et fitness        GL-TRIATHLON   349
# 5    Appareils sport et fitness               GL-TW   599
# 6    Appareils sport et fitness            GL-ELSII   159
# 7    Appareils sport et fitness             GL-P400   349
# 8    Appareils sport et fitness      VEI-3401060242     1
# 9            Électrodes et gels           GENERIQUE   8.9
# 10           Électrodes et gels           GENERIQUE   5.6
# 11           Électrodes et gels           GENERIQUE   5.9
# 12           Électrodes et gels           GENERIQUE   3.9
# 13           Électrodes et gels        CEFAR-COMPEX  None
# 14           Électrodes et gels        CEFAR-COMPEX   5.8
# 15           Électrodes et gels        CEFAR-COMPEX   9.7
# 16           Électrodes et gels        CEFAR-COMPEX  14.6
# 17           Électrodes et gels        CEFAR-COMPEX   5.4
# 18           Électrodes et gels        CEFAR-COMPEX   5.4
# 19           Électrodes et gels        CEFAR-COMPEX   5.8
# 20           Électrodes et gels        CEFAR-COMPEX     4
# 21           Électrodes et gels        CEFAR-COMPEX  21.4
# 22           Électrodes et gels           GENERIQUE  None
# 23           Électrodes et gels        CEFAR-COMPEX   6.9
# 24           Électrodes et gels               CEFAR   5.9
# 25           Électrodes et gels              COMPEX   9.9
# 26           Électrodes et gels              COMPEX   9.9
# 27           Électrodes et gels  PHYSIOTHERAPIE.com    27
# 28           Électrodes et gels         CHATTANOOGA     6
# 29           Électrodes et gels               CEFAR    12
# ..                          ...                 ...   ...
# 157       Câbles et adaptateurs               CEFAR    19
# 158       Câbles et adaptateurs         CHATTANOOGA  None
# 159       Câbles et adaptateurs            SPORECUP    12
# 160       Câbles et adaptateurs         CHATTANOOGA    22
# 161      Batteries et chargeurs               CEFAR    62
# 162      Batteries et chargeurs               CEFAR    63
# 163      Batteries et chargeurs              GLOBUS    35
# 164      Batteries et chargeurs              GLOBUS    35
# 165      Batteries et chargeurs           GENERIQUE    50
# 166      Batteries et chargeurs           GENERIQUE    25
# 167      Batteries et chargeurs           GENERIQUE    10
# 168      Batteries et chargeurs           GENERIQUE    35
# 169      Batteries et chargeurs               CEFAR    63
# 170      Batteries et chargeurs              COMPEX    59
# 171      Batteries et chargeurs              COMPEX    59
# 172      Batteries et chargeurs              COMPEX    69
# 173      Batteries et chargeurs               CEFAR    61
# 174      Batteries et chargeurs               CEFAR    99
# 175      Batteries et chargeurs              COMPEX    71
# 176      Batteries et chargeurs              GLOBUS    35
# 177      Batteries et chargeurs              GLOBUS    39
# 178      Batteries et chargeurs              COMPEX    63
# 179      Batteries et chargeurs              COMPEX    99
# 180      Batteries et chargeurs            SPORECUP  24.9
# 181      Batteries et chargeurs              GLOBUS    49
# 182      Batteries et chargeurs              GLOBUS    29
# 183      Batteries et chargeurs              GLOBUS    35
# 184      Batteries et chargeurs            SPORECUP    38
# 185      Batteries et chargeurs              GLOBUS    39
# 186      Batteries et chargeurs              GLOBUS    49
#
# [187 rows x 5 columns]

# %%
marques = []
noms = physio_df['nom']
noms

for nom in noms:
    marque = nom.split(" ")[0]
    marques.append(marque)

marques
physio_df['marque'] = marques

# %%
physio_df[11:20]
# Out:
#        id                                                nom  \
# 11    223                      GENERIQUE Electrodes 50x90 mm
# 12    227                 GENERIQUE Flacon de gel conducteur
# 13  21783           CEFAR-COMPEX Kit Electrodes Cefar-Compex
# 14     14  CEFAR-COMPEX Jeu 2 electrodes à Fil Dura-stick...
# 15    116            CEFAR-COMPEX Electrodes Premium 50x50mm
# 16    117           CEFAR-COMPEX Electrodes Premium 50x90 mm
# 17    187           CEFAR-COMPEX Jeu de 4 électrodes Ø 32 mm
# 18    188             CEFAR-COMPEX Electrodes rondes Ø 50 mm
# 19    190  CEFAR-COMPEX Jeu de 4 électrodes à Fil Dura-st...
#
#              categorie     reference  prix        marque
# 11  Électrodes et gels     GENERIQUE   5.9     GENERIQUE
# 12  Électrodes et gels     GENERIQUE   3.9     GENERIQUE
# 13  Électrodes et gels  CEFAR-COMPEX  None  CEFAR-COMPEX
# 14  Électrodes et gels  CEFAR-COMPEX   5.8  CEFAR-COMPEX
# 15  Électrodes et gels  CEFAR-COMPEX   9.7  CEFAR-COMPEX
# 16  Électrodes et gels  CEFAR-COMPEX  14.6  CEFAR-COMPEX
# 17  Électrodes et gels  CEFAR-COMPEX   5.4  CEFAR-COMPEX
# 18  Électrodes et gels  CEFAR-COMPEX   5.4  CEFAR-COMPEX
# 19  Électrodes et gels  CEFAR-COMPEX   5.8  CEFAR-COMPEX

# %%
physio_df['marque'].describe()
# Out:
# count             187
# unique             16
# top       CHATTANOOGA
# freq               40
# Name: marque, dtype: object

# %%
physio_df['marque'].value_counts()
# Out:
# CHATTANOOGA           40
# COMPEX                27
# GLOBUS                27
# CEFAR                 19
# GENERIQUE             17
# FERROX                17
# CEFAR-COMPEX          11
# NAGGURA               10
# SPORECUP               5
# PHYSIOTHERAPIE.com     3
# ECOPOSTURAL            3
# VEINOPLUS              3
# NEUROTRAC              2
# SCHWA                  1
# GYMNA                  1
# COLSON                 1
# Name: marque, dtype: int64

# %%
physio_df[physio_df['marque']=="CHATTANOOGA"]
# Out:
#         id                                                nom  \
# 28    1215           CHATTANOOGA Flacon de Gel ultrason 250ml
# 34    3881       CHATTANOOGA Kit électrodes Vacuum 60 mm (x4)
# 35    3883       CHATTANOOGA Kit éponges Vacuum de 60 mm (X4)
# 38    6029  CHATTANOOGA Eponges pour electrodes vacuum de ...
# 49   17684       CHATTANOOGA Tabouret Standard Galaxy/Montane
# 50    7706               CHATTANOOGA Table GALAXY 2 Plans DOS
# 51    8689                   CHATTANOOGA Table GALAXY 4 Plans
# 52    8685                   CHATTANOOGA Table GALAXY 3 Plans
# 53    8692                   CHATTANOOGA Table GALAXY 5 Plans
# 71    3006             CHATTANOOGA Coussins MONTANE Demi-lune
# 72    3007                  CHATTANOOGA Coussins MONTANE Rond
# 73    3005              CHATTANOOGA Coussins MONTANE Triangle
# 74   17684       CHATTANOOGA Tabouret Standard Galaxy/Montane
# 75    1527    CHATTANOOGA Table MONTANE Columbia Fixe 2 plans
# 76    2722   CHATTANOOGA Table MONTANE Tatras Gerlach 2 plans
# 77   17577           CHATTANOOGA Table MONTANE Tatras 2 plans
# 78   17589            CHATTANOOGA Table MONTANE Atlas 3 plans
# 79   17651            CHATTANOOGA Table MONTANE Taurus Bobath
# 80   17609             CHATTANOOGA Table MONTANE Alps 5 plans
# 81   17681  CHATTANOOGA Table MONTANE Dolomites Examen 2 p...
# 82   17631            CHATTANOOGA Table MONTANE Andes 7 plans
# 93     664       CHATTANOOGA Sacoche de transport CefarCompex
# 95    3881       CHATTANOOGA Kit électrodes Vacuum 60 mm (x4)
# 96    3883       CHATTANOOGA Kit éponges Vacuum de 60 mm (X4)
# 97    6029  CHATTANOOGA Eponges pour electrodes vacuum de ...
# 98    6030     CHATTANOOGA Electrodes vacuum de 90 mm (unité)
# 99    6207  CHATTANOOGA Câble 1/2 pour électrodes vacuum N...
# 100   6208  CHATTANOOGA Câble 3/4 pour électrodes vacuum (...
# 105  12466       CHATTANOOGA Kit électrodes Vacuum 30 mm (x4)
# 106  12467       CHATTANOOGA Kit électrodes Vacuum 90 mm (x4)
# 107  12468       CHATTANOOGA Kit éponges Vacuum de 90 mm (X4)
# 108  12469       CHATTANOOGA Kit éponges Vacuum de 30 mm (X4)
# 110  12033                       CHATTANOOGA Compex Pro Rehab
# 111  12035                      CHATTANOOGA Compex Pro Physio
# 126  12034                     CHATTANOOGA Compex Pro - Theta
# 127  12037               CHATTANOOGA Compex Wireless Pro 2 CH
# 129  17697               CHATTANOOGA Compex Wireless Pro 4 CH
# 130  22835  CHATTANOOGA Compex Wireless Pro 2 CH Standard ...
# 158   3451            CHATTANOOGA Câbles Stim Intelect Mobile
# 160   3560  CHATTANOOGA Câble adaptateur 2 fiches bananes ...
#
#                       categorie          reference  prix       marque
# 28           Électrodes et gels        CHATTANOOGA     6  CHATTANOOGA
# 34           Électrodes et gels        CHATTANOOGA   108  CHATTANOOGA
# 35           Électrodes et gels        CHATTANOOGA    13  CHATTANOOGA
# 38           Électrodes et gels        CHATTANOOGA    16  CHATTANOOGA
# 49    Tables électriques Galaxy        CHATTANOOGA   199  CHATTANOOGA
# 50    Tables électriques Galaxy        CHATTANOOGA  1730  CHATTANOOGA
# 51    Tables électriques Galaxy        CHATTANOOGA  1805  CHATTANOOGA
# 52    Tables électriques Galaxy        CHATTANOOGA  1930  CHATTANOOGA
# 53    Tables électriques Galaxy        CHATTANOOGA  2100  CHATTANOOGA
# 71   Tables électriques Montane        CHATTANOOGA    35  CHATTANOOGA
# 72   Tables électriques Montane        CHATTANOOGA    39  CHATTANOOGA
# 73   Tables électriques Montane        CHATTANOOGA    45  CHATTANOOGA
# 74   Tables électriques Montane        CHATTANOOGA   199  CHATTANOOGA
# 75   Tables électriques Montane        CHATTANOOGA   495  CHATTANOOGA
# 76   Tables électriques Montane        CHATTANOOGA  2520  CHATTANOOGA
# 77   Tables électriques Montane        CHATTANOOGA  2520  CHATTANOOGA
# 78   Tables électriques Montane        CHATTANOOGA  2765  CHATTANOOGA
# 79   Tables électriques Montane        CHATTANOOGA  2890  CHATTANOOGA
# 80   Tables électriques Montane        CHATTANOOGA  3025  CHATTANOOGA
# 81   Tables électriques Montane        CHATTANOOGA  3149  CHATTANOOGA
# 82   Tables électriques Montane        CHATTANOOGA  3529  CHATTANOOGA
# 93           Accessoires Divers        CHATTANOOGA   110  CHATTANOOGA
# 95           Accessoires Divers        CHATTANOOGA   108  CHATTANOOGA
# 96           Accessoires Divers        CHATTANOOGA    13  CHATTANOOGA
# 97           Accessoires Divers        CHATTANOOGA    16  CHATTANOOGA
# 98           Accessoires Divers        CHATTANOOGA    49  CHATTANOOGA
# 99           Accessoires Divers        CHATTANOOGA    66  CHATTANOOGA
# 100          Accessoires Divers        CHATTANOOGA    66  CHATTANOOGA
# 105          Accessoires Divers        CHATTANOOGA   105  CHATTANOOGA
# 106          Accessoires Divers        CHATTANOOGA   140  CHATTANOOGA
# 107          Accessoires Divers        CHATTANOOGA    16  CHATTANOOGA
# 108          Accessoires Divers        CHATTANOOGA     8  CHATTANOOGA
# 110     Douleurs et rééducation      CH-EL-2533110   399  CHATTANOOGA
# 111     Douleurs et rééducation      CH-EL-2535110   999  CHATTANOOGA
# 126     Douleurs et rééducation      CH-EL-2534810   599  CHATTANOOGA
# 127     Douleurs et rééducation      CH-EL-2532660   799  CHATTANOOGA
# 129     Douleurs et rééducation      CH-EL-2532119   999  CHATTANOOGA
# 130     Douleurs et rééducation  CH-EL-2532660-REC   499  CHATTANOOGA
# 158       Câbles et adaptateurs        CHATTANOOGA  None  CHATTANOOGA
# 160       Câbles et adaptateurs        CHATTANOOGA    22  CHATTANOOGA

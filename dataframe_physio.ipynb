# %%
import pandas as pd

physio_df = pd.read_excel("catalog_physio_20181129.xlsx", encoding="utf-8")

# %%
physio_df
# Out:
#          id                                                nom  \
# 0      82.0                                       GLOBUS Elite
# 1      85.0                                     GLOBUS Duo Pro
# 2    3116.0                                      SPORECUP XTR4
# 3    5884.0                                  GLOBUS Activa 700
# 4    5889.0                               GLOBUS Triathlon Pro
# 5    5893.0                                  GLOBUS The Winner
# 6    5931.0                                   GLOBUS Elite SII
# 7    5939.0                                 GLOBUS Premium 400
# 8   11066.0                          VEINOPLUS Veinoplus Sport
# 9     115.0            GENERIQUE Electrodes 50x90 mm 2 sorties
# 10    222.0              GENERIQUE Electrodes carrées 50x50 mm
# 11    223.0                      GENERIQUE Electrodes 50x90 mm
# 12    227.0                 GENERIQUE Flacon de gel conducteur
# 13  21783.0           CEFAR-COMPEX Kit Electrodes Cefar-Compex
# ...
